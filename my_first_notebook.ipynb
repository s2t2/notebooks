# %% [markdown]
# <a href="https://colab.research.google.com/github/s2t2/notebooks/blob/main/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NYU TECH 2335 - Exam (Summer 2020)
#
# Hello and welcome to this exam!
#
# ## Setup Instructions
#
#   1. Please take a moment to visit the "File" menu and select "Save a copy in Drive" to create a copy of this notebook under your own control (using your NYU account).
#   2. Rename your document to include your NYU Net ID (e.g. "NYU TECH 2335 - Exam - 2020 - User123").
#   3. Visit the "Share" settings at the top right of your new notebook to share your notebook with the instructors: mrossett@stern.nyu.edu AND hns292@nyu.edu.
#   4. Run the setup code cell below with the "wget" command in it, to download the CSV file required for Question 3.
#
# ## Instructions
#
#   + Read the questions below. Each question is described in a text cell and provides some starter code in a corresponding code cell. Your mission is to write more code in the code cell, to produce the desired output.
#
#   + You shouldn't need to modify any of the contents of the text cells, or any of the starter code provided.
#
#   + At any time, you may press the "play" button at the top left of any code cell to run the code and see if it is producing the desired results.
#
#   + Optionally revise your code and re-run as many times as necessary, within the time provided, to make your code work.
#
#   + You will have ~~75 minutes~~ AS MUCH TIME AS YOU NEED (UP TO THREE HOURS) to work on answering the questions.
#
#
# ## Academic Integrity
#
# Please abide by these rules to ensure the academic integrity of this exam.
#
# This exam is "open book" but NOT collaborative, which means you:
#
#   1. MAY consult any of your own notes or personal work product, notes from the course repository, Google, Stack Overflow, official Python documentation, etc. If you do use online resources, prefer to include a commented-out URL to accompany the Python code.
#   2. MAY NOT consult or communicate with any other human! This means no talking, texting, or chatting with any fellow students.
#
# You're meant to be able to solve all the questions and get a 100%. Take your time and take pride in your work and use this exam as a learning opportunity!
#
# ## Submission Instructions
#
# When when you're done answering the questions below, fill out this [Google Form](https://forms.gle/b985S9U7YMTc18RW7) to submit the URL of your notebook.
#
# ## Evaluation
#
# The weight of each question is detailed in the table below.
#
# question | weight
# --- | ---
# 1-A | 8%
# 1-B | 8%
# 1-C | 8%
# 1-D | 8%
#
# question | weight
# --- | ---
# 2-A | 8%
# 2-B | 8%
# 2-C | 10%
#
# question | weight
# --- | ---
# 3-A | 8%
# 3-B | 8%
# 3-C | 8%
# 3-D | 16%
#
# There is no penalty for guessing, however partial credit will likely not be awarded.

# %%
#
# SETUP CODE CELL
#
# Run this cell once to download the CSV file into your notebook's environment.
# Then when you run the Question 3 code cell below, you should see it is "True" that the file exists.
# !wget -q https://gist.githubusercontent.com/s2t2/f2b01347c06258cad28e7331f1e9320f/raw/b61ea33cd18aaadf885eb04544d921c9d9445e21/albums.csv

# %% [markdown]
# ### Question 1
#
# Given the Python variable called `trip` provided below, write Python code which references that variable to perform each of the following tasks...
#
# #### Part A
#
# “Print” a human-friendly message to denote the driver’s first name (i.e. `“Your driver is Danny"`).
#
# #### Part B
#
# Assuming stops can get added or removed at any time, “print” the number of stops this trip makes (i.e. `3`).
#
# #### Part C
#
# Assuming the stops will always be listed in ascending order of their stop sequence, “print” the destination of the LAST stop (i.e. `“Washington Square”`).
#
#
# #### Part D
#
#
# Loop through each of the trip’s stops and “print” that stop’s passenger name, one at a time (i.e. `“Vishal”`, then `“Clara”`, then `“Lee”`, each on a separate line):

# %%
#
# QUESTION 1
#

trip = {
    "driver": {
        "first_name": "Danny",
        "last_name": "Dreyfus",
        "avg_rating": 3.6,
        "total_rides": 950
    },
    "vehicle": {
        "make": "Tesla",
        "model": "Cybertruck",
        "year": 2021,
        "color": "silver"
    },
    "rideshare": True,
    "pickup_location": "Grand Central Terminal",
    "stops": [
        {"sequence": 1, "passenger": "Vishal", "destination": "Madison Square", "fare": 3.99},
        {"sequence": 2, "passenger": "Clara", "destination": "Union Square", "fare": 5.99},
        {"sequence": 3, "passenger": "Lee", "destination": "Washington Square", "fare": 7.99}
    ]
}

print("------------------")
print("PROCESSING RIDESHARE DATA...")
print("------------------")

#
# PART A
#

# todo: write some Python code here to answer the question!


#
# PART B
#

# todo: write some Python code here to answer the question!


#
# PART C
#

# todo: write some Python code here to answer the question!


#
# PART D
#

# todo: write some Python code here to answer the question!
# Out:
# ------------------
# PROCESSING RIDESHARE DATA...
# ------------------

# %% [markdown]
# ### Question 2
#
# Given the Python variable called `tweets` provided below, write Python code which references that variable to perform each of the following tasks...
#
# #### Part A
#
# “Print” the screen name of the user who authored the first tweet (i.e. `“sandwhoa”`).
#
#
# #### Part B
#
# Of all the tweets which include the phrase `“@sandwhoa”` in their full text, “print” the screen name of the user who authored that tweet, each on a separate line (i.e. `“person2”`, then `“person3”`).
#
# #### Part C
#
# Of all the tweets which include the phrase `“@sandwhoa”` in their full text, determine which tweet has the greatest number of likes, and then “print” the screen name of the user who authored that tweet (i.e. `“person3”`). FYI: Assume the tweet order can change at any time and has no relationship with the number of likes.

# %%
#
# QUESTION 2
#

tweets = [
    {
        "id": 100200297,
        "full_text": "Look at this delicious sandwich!",
        "img_url": "https://sandwhoa.com/sandwich.png",
        "user": {"screen_name": "sandwhoa", "followers": 5000},
        "likes_count": 150
    },
    {
        "id": 100200298,
        "full_text": "I love sandwiches",
        "img_url": None,
        "user": {"screen_name": "person1", "followers": 100},
        "likes_count": 5
    },
    {
        "id": 100200299,
        "full_text": "@sandwhoa yumm...",
        "img_url": None,
        "user": {"screen_name": "person2", "followers": 200},
        "likes_count": 10
    },
    {
        "id": 100200300,
        "full_text": "@sandwhoa that sandwich looks amazing!!",
        "img_url": None,
        "user": {"screen_name": "person3", "followers": 300},
        "likes_count": 35
    },
    {
        "id": 100200301,
        "full_text": "I ate a great sandwich today",
        "img_url": None,
        "user": {"screen_name": "person4", "followers": 400},
        "likes_count": 50
    }
]

print("------------------")
print("PROCESSING SOCIAL MEDIA DATA...")
print("------------------")

#
# PART A
#

# todo: write some Python code here to answer the question!


#
# PART B
#

# todo: write some Python code here to answer the question!


#
# PART C
#

# todo: write some Python code here to answer the question!
# Out:
# ------------------
# PROCESSING SOCIAL MEDIA DATA...
# ------------------

# %% [markdown]
# ### Question 3
#
# Given the provided "albums.csv" file and a valid filepath variable reference to that file's location (i.e. `csv_filepath`), write Python code which references that variable to read the CSV data and perform each of the following tasks...
#
# > HINT: you might need to use the `csv` module or the `pandas` package. If you'd like to use the `pandas` package, it should already be installed for you, so it is not neccessary to `pip install pandas`.
#
# > FYI: the following table depicts a sample of rows from the CSV file...
#
# > artist_id | artist_name | album_id | album_title
# > --- | ---  | ---  | ---
# > 1 | AC/DC | 1 | For Those About To Rock We Salute You
# > 1 | AC/DC | 4 | Let There Be Rock
# > 3 | Aerosmith | 5 | Big Ones
# > 4 | Alanis Morissette | 6 | Jagged Little Pill
# > 68 | Miles Davis | 48 | The Essential Miles Davis [Disc 1]
# > 68 | Miles Davis | 49 | The Essential Miles Davis [Disc 2]
# > 59 | Santana | 197 | Santana - As Years Go By
# > 59 | Santana | 198 | Santana Live
#
# #### Part A
#
# "Print" a list of the CSV file's column names (i.e. `['artist_id', 'artist_name', 'album_id', 'album_title']`).
#
# #### Part B
#
# "Print" the number of rows in the CSV file, excluding the header row (i.e. `347`).
#
# #### Part C
#
# Assuming each "artist_id" represents a unique artist, "print" the number of unique artists (i.e. `204`).
#
# #### Part D
#
# Assuming each "album_id" represents a unique album, identify which five artists have the most albums, then loop through each of the top five artists and “print” that artist's name and corresponding album count, one at a time, each on a separate line.
#
# FYI: the following table depicts the correct top five artists and their corresponding album counts...
#
# | artist_name   | album_count |
# |---------------|----------|
# | Iron Maiden   | 21       |
# | Led Zeppelin  | 14       |
# | Deep Purple   | 11       |
# | Metallica     | 10       |
# | U2            | 10       |

# %%
#
# QUESTION 3
#

import os

csv_filepath = "albums.csv"

print("------------------")
print("PROCESSING SONG DATA FROM CSV...", csv_filepath)
print("CSV FILE EXISTS?", os.path.exists(csv_filepath)) #> should be True, otherwise run the preceding setup code cell (one time only)
print("------------------")

# todo: import csv module or pandas package here!

#
# PART A
#

# todo: write some Python code here to answer the question!

#
# PART B
#

# todo: write some Python code here to answer the question!


#
# PART C
#

# todo: write some Python code here to answer the question!

#
# PART D
#

# todo: write some Python code here to answer the question!
# Out:
# ------------------
# PROCESSING SONG DATA FROM CSV... albums.csv
# CSV FILE EXISTS? False
# ------------------
